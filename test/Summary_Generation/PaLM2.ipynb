# %%
import pandas as pd
import google.generativeai as palm
from tqdm import tqdm
from time import sleep

# %%
df = pd.read_csv('../../data/df/31_data_df.csv')
df.head()
# Out:
#    Unnamed: 0 Extracted RER #  \
# 0           0     RER-1171822
# 1           1     RER-1171836
# 2           2     RER-1172079
# 3           3     RER-1173033
# 4           4     RER-1173035
#
#                                    Links to Document  \
# 0  RER-1171822  Letter of Acceptance, Waiver and ...
# 1          RER-1171836  _ (wolterskluwerfs.com)  /
# 2  RER-1172079   Administrative Proceedings In th...
# 3  RER-1173033  Letter of Acceptance, Waiver and ...
# 4  RER-1173035   Letter of Acceptance, Waiver and...
#
#                                             pdf_link  Tracking ID  \
# 0  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1171822
# 1  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1171836
# 2  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1172079
# 3  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1173033
# 4  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1173035
#
# ...

# %%
text = df['text_extracted'][2]

# %%
template = f"""
              You are a compliance officer who works at a financial institution. You need to create a summary that covers all important points. Summarize the following text.
              ```{text}```
              SUMMARY:
           """

# %%
palm.configure(api_key='AIzaSyDSKlHyE2Q1b2arv30vNm_CaihzSJhlHJA')

# %%
# Create a new conversation
response = palm.chat(messages=template)

# Last contains the model's response:
result = response.last

# %%
result

# %%
result_palm = []
for i in tqdm(range(len(df['text_extracted']))):
    text = df['text_extracted'][i]
    template = f"""
              You are a compliance officer who works at a financial institution. You need to create a summary that covers all important points. Summarize the following text.
              ```{text}```
              SUMMARY:
           """
    response = palm.chat(messages=template)
    result = response.last
    result_palm.append(result)
    sleep(5)

df['PaLM'] = result_palm
df.head()

# %%
from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm
import google.generativeai
import os

google_api_key = 'AIzaSyDSKlHyE2Q1b2arv30vNm_CaihzSJhlHJA'

prompt = f"""
You are a novice who has no experience in financial matters. You've been asked to summarize the following text, even though you don't understand it. Try your best to summarize, but remember, you've never dealt with financial topics before.
```{text}```
ATTEMPTED SUMMARY:
"""

llm = GooglePalm(google_api_key=google_api_key)
llm.temperature = 0


prompts = [prompt]
llm_result = llm._generate(prompts)

print(llm_result.generations[0][0].text)
# Out:
# CFI, Mantei, and Makharia have agreed to settle charges that they violated the antifraud provisions of the federal securities laws and Regulation BI by making unsuitable recommendations of variable annuities (VARPs) to senior investors.
#
# CFI failed to implement its written supervisory procedures designed to prevent and detect unsuitable recommendations of VARPs, and Mantei failed to follow the procedures that were in place. CFI also failed to make and keep required customer account records.
#
# ...

# %%
result_palm = []
for i in tqdm(range(len(df['text_extracted']))):
    text = df['text_extracted'][i]
    template = f"""
              You are a compliance officer who works at a financial institution. You need to create a summary that covers all important points. Summarize the following text.
              ```{text}```
              SUMMARY:
           """
    llm = GooglePalm(google_api_key=google_api_key)
    llm.temperature = 0
    prompts = [prompt]
    llm_result = llm._generate(prompts)
    result_palm.append(llm_result.generations[0][0].text)
    sleep(5)

df['PaLM'] = result_palm
df.head()
# Out:
# 100%|██████████| 31/31 [06:11<00:00, 12.00s/it]
#    Unnamed: 0 Extracted RER #  \
# 0           0     RER-1171822
# 1           1     RER-1171836
# 2           2     RER-1172079
# 3           3     RER-1173033
# 4           4     RER-1173035
#
#                                    Links to Document  \
# 0  RER-1171822  Letter of Acceptance, Waiver and ...
# 1          RER-1171836  _ (wolterskluwerfs.com)  /
# 2  RER-1172079   Administrative Proceedings In th...
# 3  RER-1173033  Letter of Acceptance, Waiver and ...
# 4  RER-1173035   Letter of Acceptance, Waiver and...
#
#                                             pdf_link  Tracking ID  \
# 0  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1171822
# 1  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1171836
# 2  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1172079
# 3  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1173033
# 4  https://rcm.wolterskluwerfs.com/WKFSUploadedFi...  RER-1173035
#
# ...

# %%
df['PaLM'][4]
# Out:
# 'The Securities and Exchange Commission (SEC) has ordered Capital Financial\nInsurance (CFI) and its former branch manager, Manoj Mantei, to pay disgorgement,\nprejudgment interest, and civil money penalties totaling $1,093,552 and $441,642,\nrespectively. The SEC also censured CFI and suspended Mantei from acting in a supervisory\ncapacity with any broker, dealer, investment adviser, municipal securities dealer, municipal\nadvisor, transfer agent, or nationally recognized statistical rating organization for six months.\nThe SEC found that CFI and Mantei recommended unsuitable structured products to\nninety-four senior investors without conducting the required suitability reviews. The SEC also\nfound that CFI failed to maintain and preserve required customer account information and\nfailed to make and keep current a record indicating that, for each change in a customer’s\naccount investment objectives, CFI furnished the customer with a copy of the updated account\nrecord or alternati
# ...

# %%
df.to_csv('PaLM.csv', index=False)
